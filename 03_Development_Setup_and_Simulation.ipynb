# %% [markdown]
# # CN7050 Coursework – Intelligent Multi-Agent Customer Service System
# **Notebook:** 03_Development_Setup_and_Simulation.ipynb
# **Author:** [Your Name]
# **Platform:** Google Colab (Python 3.11, CPU runtime)
# **Description:** This notebook sets up the development environment and runs basic simulation for the multi-agent customer-service system.

# %%
# Install required packages
# !pip install -q pandas numpy scikit-learn nltk spacy textblob matplotlib seaborn openai

# Download language model for spaCy
# !python -m spacy download en_core_web_sm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 79.0 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
import sys, platform, pandas, numpy, sklearn, nltk, spacy, textblob, matplotlib, seaborn
print("Environment Setup ✅")
print("Python:", sys.version.split()[0])
print("OS:", platform.platform())
print("pandas:", pandas.__version__)
print("numpy:", numpy.__version__)
print("scikit-learn:", sklearn.__version__)
print("nltk:", nltk.__version__)
print("spacy:", spacy.__version__)
print("textblob:", textblob.__version__)
print("matplotlib:", matplotlib.__version__)
print("seaborn:", seaborn.__version__)
# Out:
# Environment Setup ✅
# Python: 3.12.12
# OS: Linux-6.6.105+-x86_64-with-glibc2.35
# pandas: 2.2.2
# numpy: 2.0.2
# scikit-learn: 1.6.1
# nltk: 3.9.1
# spacy: 3.8.7
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-2919740373.py in <cell line: 0>()
#       8 print("nltk:", nltk.__version__)
#       9 print("spacy:", spacy.__version__)
# ---> 10 print("textblob:", textblob.__version__)
#      11 print("matplotlib:", matplotlib.__version__)
#      12 print("seaborn:", seaborn.__version__)
#
# AttributeError: module 'textblob' has no attribute '__version__'

# %%
import sys, platform, pandas, numpy, sklearn, nltk, spacy, textblob, matplotlib, seaborn
print("Environment Setup ✅")
print("Python:", sys.version.split()[0])
print("OS:", platform.platform())
print("pandas:", pandas.__version__)
print("numpy:", numpy.__version__)
print("scikit-learn:", sklearn.__version__)
print("nltk:", nltk.__version__)
print("spacy:", spacy.__version__)
# print("textblob:", textblob.__version__) # Removed as TextBlob does not have __version__
print("matplotlib:", matplotlib.__version__)
print("seaborn:", seaborn.__version__)
# Out:
# Environment Setup ✅
# Python: 3.12.12
# OS: Linux-6.6.105+-x86_64-with-glibc2.35
# pandas: 2.2.2
# numpy: 2.0.2
# scikit-learn: 1.6.1
# nltk: 3.9.1
# spacy: 3.8.7
# matplotlib: 3.10.0
# seaborn: 0.13.2

# %%
import nltk, spacy
nltk.download('punkt')
nltk.download('stopwords')
nlp = spacy.load("en_core_web_sm")
print("NLP Resources Ready ✔")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# NLP Resources Ready ✔

# %%
import os
for d in ["data", "figures", "exports"]:
    os.makedirs(d, exist_ok=True)
print("Project folders created:", os.listdir())
# Out:
# Project folders created: ['.config', 'exports', 'data', 'figures', 'sample_data']

# %%
reqs = """pandas
numpy
scikit-learn
nltk
spacy
textblob
matplotlib
seaborn
openai
"""
open("requirements.txt", "w").write(reqs)
print("requirements.txt file created successfully ✔")
# Out:
# requirements.txt file created successfully ✔

# %%
### 🧠 Reproducibility Note
This notebook is designed to be fully reproducible.
Running all cells in order will recreate:
1. Library installation and version setup
2. NLP model download
3. Folder creation
4. requirements.txt export

To replicate the environment locally:
# Out:
#   File "/tmp/ipython-input-4279544946.py", line 2
#     This notebook is designed to be fully reproducible.
#          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### 🧠 Reproducibility Note
# This notebook is designed to be fully reproducible.
# Running all cells in order will recreate:
# 1. Library installation and version setup
# 2. NLP model download
# 3. Folder creation
# 4. requirements.txt export
#
# To replicate the environment locally:
